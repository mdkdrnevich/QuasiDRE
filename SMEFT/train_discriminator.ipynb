# %%
import sys
sys.path.append('../')
import os.path as osp

import utils

import torch
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import numpy as np

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cuda:0
# /home/mdrnevich/dev/QuasiML_paper/QuasiML/SMEFT/../utils/__init__.py:5: UserWarning: The recommended fonts to use plothist were not found. You can install them by typing 'install_latin_modern_fonts' in your terminal.
#
#   from . import plotting

# %% [markdown]
# ## Initiate the datasets

# %%
DATA_NUM = ""
TEST_NUM = ""
LOSS = "bce"

MODEL_NAMES = ["new", "SMM", "old_SMMc", "old_SMMr", "SMMc", "SMMr"]
CHOICE = 3
MODEL_NAME = MODEL_NAMES[CHOICE]

training_settings = {}

source_file = "./data/SMEFT_SM_combined_tuple{}_discriminant_{}".format(DATA_NUM, MODEL_NAME)
target_file = "./data/SMEFT_EFT_combined_tuple{}_total_variation".format(DATA_NUM)


train_base_dataset = utils.preprocessing.Dataset(source_file + "_train.npy", 0)
valid_base_dataset = utils.preprocessing.Dataset(source_file + "_val.npy", 0)

train_target_dataset = utils.preprocessing.Dataset(target_file + "_train.npy", 1)
valid_target_dataset = utils.preprocessing.Dataset(target_file + "_val.npy", 1)

training_settings.update({
    "source_file": source_file,
    "target_file": target_file,
})

# %% [markdown]
# ## Load the data

# %%
source_weight_norm = train_base_dataset.process(normalize_weights=True)
source_valid_weight_norm = valid_base_dataset.process(normalize_weights=True)

target_weight_norm = train_target_dataset.process(normalize_weights=True)
valid_target_dataset.process(normalize_weights=True)
# Out:
# tensor(0.0251)

# %%
train_generator_data = utils.preprocessing.CombinedDataset(train_base_dataset, train_target_dataset)
valid_generator_data = utils.preprocessing.CombinedDataset(valid_base_dataset, valid_target_dataset)

# %% [markdown]
# ## Do some data preprocessing for standardized inputs and weights

# %%
X_scaler, train_weight_norm = utils.preprocessing.get_scaling(train_generator_data)
_, valid_weight_norm = utils.preprocessing.get_scaling(valid_generator_data)
print(train_weight_norm, valid_weight_norm)
# Out:
# 100%|██████████| 1517/1517 [00:13<00:00, 115.87it/s]
# 100%|██████████| 350/350 [00:02<00:00, 119.84it/s]
# tensor(1.0000) tensor(1.0000)

# %% [markdown]
# ## Prepare the data for training

# %%
random_seed = 0

torch.manual_seed(random_seed)
batch_size = int(2**8)
training_settings.update({
    "batch_size": batch_size,
    "random_seed": random_seed
})

train_loader = DataLoader(train_generator_data, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_generator_data, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Construct the model

# %%
inputs = 16
hidden_nodes = [128, 256, 128]
#hidden_nodes = [64, 64, 64] # [128, 256, 128]
outputs = 1

t0 = None
t1 = None
if LOSS in ["mse", "pare"]:
    t0 = 25619
    t1 = 58
    model = utils.models.Classifier(inputs, hidden_nodes, outputs, final_activation="linear")
else:
    model = utils.models.Classifier(inputs, hidden_nodes, outputs)
print(model)
print("----------")

model = model.to(DEVICE)

learning_rate = 3e-5
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

training_settings.update({
    "learning_rate": learning_rate,
    "optimizer": "Adam"
})

model_path = osp.join("models/discriminant_{}_classifier{}_{}_batch{}".format(MODEL_NAME, TEST_NUM, LOSS, batch_size))
print(model_path)
# Out:
# Classifier(
#   (model): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )
# ----------
# models/discriminant_old_SMMr_classifier_bce_batch256

# %% [markdown]
# ## Perform the training

# %%
n_epochs = 1500
stale_epochs = 0
best_valid_loss = 99999
patience = 20
max_num_batches = int(int(1e5) / batch_size)
t = tqdm(range(0, n_epochs))

training_losses = [utils.train.test(
        model,
        train_loader,
        X_scaler,
        loss=LOSS,
        t0=t0,
        t1=t1,
        weight_norm=train_weight_norm,
        max_num_batches=max_num_batches,
        device=DEVICE,
        progress_bar=False,
        leave=False
    )[1],]
validation_losses = [utils.train.test(
        model,
        valid_loader,
        X_scaler,
        loss=LOSS,
        t0=t0,
        t1=t1,
        weight_norm=valid_weight_norm,
        device=DEVICE,
        progress_bar=False,
        leave=False
    )[1],]


for epoch in t:
    loss = utils.train.train(
        model,
        optimizer,
        train_loader,
        X_scaler,
        loss=LOSS,
        t0=t0,
        t1=t1,
        weight_norm=train_weight_norm,
        max_num_batches=max_num_batches,
        device=DEVICE,
        leave=bool(epoch == n_epochs - 1),
        progress_bar=False,
    )
    #loss -= optimal_train_loss
    training_losses.append(loss[1])

    valid_loss = utils.train.test(
        model,
        valid_loader,
        X_scaler,
        loss=LOSS,
        t0=t0,
        t1=t1,
        weight_norm=valid_weight_norm,
        device=DEVICE,
        leave=bool(epoch == n_epochs - 1),
        progress_bar=False,
    )
    validation_losses.append(valid_loss[1])
    print("Epoch: {:02d}, Training Loss:   {:.4f}".format(epoch, loss[1]))
    print("           Validation Loss: {:.4f}".format(valid_loss[1]))

    if valid_loss[1] < best_valid_loss:
        best_valid_loss = valid_loss[1]
        training_settings.update({
            "n_epochs": epoch+1,
            "training_losses": training_losses,
            "validation_losses": validation_losses
        })
        model_metadata = utils.train.get_model_metadata(training_settings, model, X_scaler, train_weight_norm)
        utils.train.save_model_data(model, model_metadata, name=model_path, save_onnx=False, device=DEVICE)
        print("New best model saved to: {}.zip".format(model_path))
        #torch.save(model.state_dict(), modpath)
        stale_epochs = 0
    else:
        print("Stale epoch")
        stale_epochs += 1
    if stale_epochs >= patience:
        print("Early stopping after %i stale epochs" % patience)
        break
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch: 00, Training Loss:   0.6915
#            Validation Loss: 0.6930
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 01, Training Loss:   0.6907
#            Validation Loss: 0.6928
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 02, Training Loss:   0.6918
#            Validation Loss: 0.6927
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 03, Training Loss:   0.6891
#            Validation Loss: 0.6927
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 04, Training Loss:   0.6883
#            Validation Loss: 0.6927
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 05, Training Loss:   0.6928
#            Validation Loss: 0.6926
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 06, Training Loss:   0.6914
#            Validation Loss: 0.6926
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 07, Training Loss:   0.6905
#            Validation Loss: 0.6926
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 08, Training Loss:   0.6907
#            Validation Loss: 0.6925
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 09, Training Loss:   0.6913
#            Validation Loss: 0.6924
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 10, Training Loss:   0.6901
#            Validation Loss: 0.6925
# Stale epoch
# Epoch: 11, Training Loss:   0.6913
#            Validation Loss: 0.6924
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 12, Training Loss:   0.6895
#            Validation Loss: 0.6924
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 13, Training Loss:   0.6892
#            Validation Loss: 0.6923
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 14, Training Loss:   0.6909
#            Validation Loss: 0.6923
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 15, Training Loss:   0.6891
#            Validation Loss: 0.6922
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 16, Training Loss:   0.6881
#            Validation Loss: 0.6922
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 17, Training Loss:   0.6894
#            Validation Loss: 0.6922
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 18, Training Loss:   0.6936
#            Validation Loss: 0.6921
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 19, Training Loss:   0.6905
#            Validation Loss: 0.6921
# Stale epoch
# Epoch: 20, Training Loss:   0.6881
#            Validation Loss: 0.6922
# Stale epoch
# Epoch: 21, Training Loss:   0.6913
#            Validation Loss: 0.6922
# Stale epoch
# Epoch: 22, Training Loss:   0.6914
#            Validation Loss: 0.6921
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 23, Training Loss:   0.6900
#            Validation Loss: 0.6922
# Stale epoch
# Epoch: 24, Training Loss:   0.6890
#            Validation Loss: 0.6921
# Stale epoch
# Epoch: 25, Training Loss:   0.6915
#            Validation Loss: 0.6921
# Stale epoch
# Epoch: 26, Training Loss:   0.6897
#            Validation Loss: 0.6921
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 27, Training Loss:   0.6886
#            Validation Loss: 0.6921
# Stale epoch
# Epoch: 28, Training Loss:   0.6904
#            Validation Loss: 0.6920
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 29, Training Loss:   0.6899
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 30, Training Loss:   0.6898
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 31, Training Loss:   0.6920
#            Validation Loss: 0.6920
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 32, Training Loss:   0.6891
#            Validation Loss: 0.6920
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 33, Training Loss:   0.6903
#            Validation Loss: 0.6920
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 34, Training Loss:   0.6874
#            Validation Loss: 0.6922
# Stale epoch
# Epoch: 35, Training Loss:   0.6898
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 36, Training Loss:   0.6901
#            Validation Loss: 0.6919
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 37, Training Loss:   0.6909
#            Validation Loss: 0.6919
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 38, Training Loss:   0.6851
#            Validation Loss: 0.6919
# Stale epoch
# Epoch: 39, Training Loss:   0.6915
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 40, Training Loss:   0.6898
#            Validation Loss: 0.6919
# Stale epoch
# Epoch: 41, Training Loss:   0.6910
#            Validation Loss: 0.6918
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 42, Training Loss:   0.6904
#            Validation Loss: 0.6919
# Stale epoch
# Epoch: 43, Training Loss:   0.6879
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 44, Training Loss:   0.6910
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 45, Training Loss:   0.6900
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 46, Training Loss:   0.6922
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 47, Training Loss:   0.6889
#            Validation Loss: 0.6918
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 48, Training Loss:   0.6901
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 49, Training Loss:   0.6893
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 50, Training Loss:   0.6884
#            Validation Loss: 0.6919
# Stale epoch
# Epoch: 51, Training Loss:   0.6899
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 52, Training Loss:   0.6923
#            Validation Loss: 0.6917
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 53, Training Loss:   0.6861
#            Validation Loss: 0.6922
# Stale epoch
# Epoch: 54, Training Loss:   0.6889
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 55, Training Loss:   0.6888
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 56, Training Loss:   0.6868
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 57, Training Loss:   0.6908
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 58, Training Loss:   0.6898
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 59, Training Loss:   0.6876
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 60, Training Loss:   0.6889
#            Validation Loss: 0.6917
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 61, Training Loss:   0.6904
#            Validation Loss: 0.6917
# Stale epoch
# Epoch: 62, Training Loss:   0.6870
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 63, Training Loss:   0.6914
#            Validation Loss: 0.6920
# Stale epoch
# Epoch: 64, Training Loss:   0.6898
#            Validation Loss: 0.6919
# Stale epoch
# Epoch: 65, Training Loss:   0.6895
#            Validation Loss: 0.6917
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 66, Training Loss:   0.6901
#            Validation Loss: 0.6917
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 67, Training Loss:   0.6893
#            Validation Loss: 0.6917
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 68, Training Loss:   0.6897
#            Validation Loss: 0.6916
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 69, Training Loss:   0.6895
#            Validation Loss: 0.6916
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 70, Training Loss:   0.6888
#            Validation Loss: 0.6918
# Stale epoch
# Epoch: 71, Training Loss:   0.6888
#            Validation Loss: 0.6916
# Stale epoch
# Epoch:
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 152, Training Loss:   0.6878
#            Validation Loss: 0.6913
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 153, Training Loss:   0.6886
#            Validation Loss: 0.6917
# Stale epoch
# Epoch: 154, Training Loss:   0.6902
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 155, Training Loss:   0.6883
#            Validation Loss: 0.6913
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 156, Training Loss:   0.6898
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 157, Training Loss:   0.6861
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 158, Training Loss:   0.6874
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 159, Training Loss:   0.6885
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 160, Training Loss:   0.6889
#            Validation Loss: 0.6913
# Stale epoch
# Epoch: 161, Training Loss:   0.6894
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 162, Training Loss:   0.6886
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 163, Training Loss:   0.6884
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 164, Training Loss:   0.6896
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 165, Training Loss:   0.6867
#            Validation Loss: 0.6916
# Stale epoch
# Epoch: 166, Training Loss:   0.6881
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 167, Training Loss:   0.6894
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 168, Training Loss:   0.6880
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 169, Training Loss:   0.6902
#            Validation Loss: 0.6913
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 170, Training Loss:   0.6897
#            Validation Loss: 0.6913
# New best model saved to: models/discriminant_old_SMMr_classifier_bce_batch256.zip
# Epoch: 171, Training Loss:   0.6836
#            Validation Loss: 0.6913
# Stale epoch
# Epoch: 172, Training Loss:   0.6890
#            Validation Loss: 0.6913
# Stale epoch
# Epoch: 173, Training Loss:   0.6892
#            Validation Loss: 0.6913
# Stale epoch
# Epoch: 174, Training Loss:   0.6875
#            Validation Loss: 0.6913
# Stale epoch
# Epoch: 175, Training Loss:   0.6868
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 176, Training Loss:   0.6892
#            Validation Loss: 0.6916
# Stale epoch
# Epoch: 177, Training Loss:   0.6876
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 178, Training Loss:   0.6926
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 179, Training Loss:   0.6874
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 180, Training Loss:   0.6860
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 181, Training Loss:   0.6896
#            Validation Loss: 0.6916
# Stale epoch
# Epoch: 182, Training Loss:   0.6869
#            Validation Loss: 0.6913
# Stale epoch
# Epoch: 183, Training Loss:   0.6865
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 184, Training Loss:   0.6878
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 185, Training Loss:   0.6875
#            Validation Loss: 0.6915
# Stale epoch
# Epoch: 186, Training Loss:   0.6900
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 187, Training Loss:   0.6880
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 188, Training Loss:   0.6883
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 189, Training Loss:   0.6851
#            Validation Loss: 0.6914
# Stale epoch
# Epoch: 190, Training Loss:   0.6888
#            Validation Loss: 0.6913
# Stale epoch
# Early stopping after 20 stale epochs

# %% [markdown]
# ### Look at loss curves

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10, 8)

starting_epoch = 1
training_loss_per_epoch = np.array(training_losses[starting_epoch:])#.mean(axis=1)
#training_std_per_epoch = np.array(training_losses[starting_epoch:]).std(axis=1)

validation_loss_per_epoch = np.array(validation_losses[starting_epoch:])#.mean(axis=1)
#validation_std_per_epoch = np.array(validation_losses[starting_epoch:]).std(axis=1)

#training_lower_bar = training_loss_per_epoch - training_std_per_epoch
#training_upper_bar = training_loss_per_epoch + training_std_per_epoch

#validation_lower_bar = validation_loss_per_epoch - validation_std_per_epoch
#validation_upper_bar = validation_loss_per_epoch + validation_std_per_epoch


t1 = np.arange(len(training_loss_per_epoch))
t2 = np.arange(len(validation_loss_per_epoch))
ax.plot(t1, training_loss_per_epoch, '-', label="Training loss", c='tab:blue')
#ax.fill_between(t1, training_lower_bar, training_upper_bar, color='tab:blue', alpha=0.30)

ax.plot(t2, validation_loss_per_epoch, '-', label="Validation loss", c='tab:orange')
#ax.fill_between(t2, validation_lower_bar, validation_upper_bar, color='tab:orange', alpha=0.30)

#ax.set_xscale('log')
ax.legend()
ax.set_xlabel("Epoch")
ax.set_ylabel("{} Loss".format(LOSS.upper()))
# Out:
# Text(0, 0.5, 'BCE Loss')
