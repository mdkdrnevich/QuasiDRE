# %%
import sys
sys.path.append('../')
import os.path as osp

import torch
from torch.utils.data import DataLoader
import numpy as np
import copy
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import utils

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#DEVICE = 'cpu'
print(DEVICE)
# Out:
# cuda:0
# /home/mdrnevich/dev/QuasiML_paper/QuasiML/SMEFT/../utils/__init__.py:5: UserWarning: The recommended fonts to use plothist were not found. You can install them by typing 'install_latin_modern_fonts' in your terminal.
#
#   from . import plotting

# %% [markdown]
# # Now create a combined model and optimize the coefficients

# %%
submodel_names = np.array(["Pos", "Neg", "Pos", "Neg"])
combos = [np.array((0,2)), #++
          np.array((0,3))] #+-

NUM_MODELS = 2

# %%
DATA_NUM = ""
TEST_NUM = ""

#batch_sizes = [int(2**6), int(2**6)]
#subdensity_model_paths = [osp.join("models/classifier{}_subdensity_{}_batch{}.zip".format(TEST_NUM, ''.join(submodel_names[combos[i]]), batch_sizes[i])) for i in range(NUM_MODELS)]

batch_sizes = [int(2**6), int(2**8)]
subdensity_model_paths = [osp.join("models/classifier{}_subdensity_{}_batch{}.zip".format(2, ''.join(submodel_names[combos[i]]), batch_sizes[i])) for i in range(NUM_MODELS)]

# %%
FINE_TUNE = False

t0 = 25619
t1 = 58
print(t0, t1, -(t0/t1)**2, -t0/t1)

mix_model = utils.models.SingleMixtureClassifier(subdensity_model_paths, which_mixture=1, t0=t0, t1=t1, fine_tune=FINE_TUNE).to(DEVICE)
# Out:
# 25619 58 -195104.9824613555 -441.7068965517241

# %%
source_file = "./data/SMEFT_SM_combined_tuple{}".format(DATA_NUM)
target_file = "./data/SMEFT_EFT_combined_tuple{}".format(DATA_NUM)

source_positive_file = source_file + "_positives"
source_negative_file = source_file + "_negatives"
target_positive_file = target_file + "_positives"
target_negative_file = target_file + "_negatives"

files = [source_positive_file, source_negative_file, target_positive_file, target_negative_file]

sum_weights = []
for f in files:
    sum_weights.append(np.load(f + "_train.npy")[:,-1].sum())

sum_weights = np.array(sum_weights)
sum_weights
# Out:
# array([12994.63  ,     0.    , 16124.036 , -3401.0479], dtype=float32)

# %%
coefficient_init = [sum_weights[0] / sum_weights[:2].sum(), sum_weights[2] / sum_weights[2:].sum()]
coefficient_init
# Out:
# [1.0, 1.2673151]

# %%
mix_model.initialize(coefficient_init)
list(mix_model.parameters())
# Out:
# [Parameter containing:
#  tensor(1., requires_grad=True),
#  Parameter containing:
#  tensor(1.2673, requires_grad=True),
#  Parameter containing:
#  tensor([[ 0.0971,  0.0914, -0.1605,  ..., -0.0997, -0.1067,  0.1413],
#          [ 0.1555,  0.1546, -0.0785,  ...,  0.0509,  0.0016,  0.2352],
#          [-0.1792, -0.0626, -0.0331,  ...,  0.1663,  0.1072,  0.0071],
#          ...,
#          [ 0.0087,  0.0221, -0.0566,  ...,  0.2473,  0.2054,  0.0165],
#          [ 0.0367,  0.1646, -0.1591,  ...,  0.2185,  0.0132,  0.3969],
#          [-0.0610, -0.0789, -0.0434,  ...,  0.3554,  0.1839, -0.0022]],
#         device='cuda:0'),
#  Parameter containing:
#  tensor([-0.1409, -0.2862, -0.4133, -0.0319, -0.2430, -0.1581, -0.0527,  0.1428,
#           0.3454,  0.1183, -0.6575, -0.0183,  0.0785,  0.0895, -0.3521, -0.0243,
#           0.0284,  0.2280, -0.4605, -0.2626, -0.2329, -0.1778,  0.0561,  0.0025,
#          -0.5353,  0.0025,  0.1979, -0.1364, -0.1528, -0.2851, -0.0075, -0.2497,
#          -0.2852, -0.4301, -0.2192,  0.1960, -0.0486, -0.1485, -0.0394,  0.3220,
#          -0.2039, -0.2101, -0.3594, -0.3508,  0.1931, -0.3273, -0.2574, -0.2121,
#          -0.1721, -0.0738, -0.2831,  0.0408, -0.3560, -0.0218, -0.0818, -0.1434,
#          -0.0024, -0.0202, -0.0191, -0.3013,  0.2855,  0.0233, -0.0976, -0.1828,
#           0.0791,  0.1179,  0.0063, -0.1133, -0.2336, -0.4058, -0.0317, -0.2518,
#          -0.1737, -0.0082, -0.1188, -0.2534, -0.2761,  0.2378, -0.0681,  0.1420,
#           0.2794, -0.4542, -0.2904, -0.0104, -0.4076,  0.0498, -0.1786,  0.1005,
#           0.0902, -0.3367, -0.1060, -0.0049, -0.1005,  0.1077, -0.4977, -0.1226,
#          -0.2713, -0.1950, -0.0757, -0.2913, -0.4595, -0.0464, -0.0741,  0.2751,
#          -0.0750, -0.0552,  0.0087, -0.3150, -0.2078, -0.4400, -0.1847, -0.0046,
#           0.2150, -0.2064,  0.0200,  0.0276, -0.2219, -0.3547,  0.0319, -0.0722,
#           0.0179,  0.0458, -0.3271, -0.3612,  0.1942, -0.1829, -0.1728,  0.1044],
#         device='cuda:0'),
#  Parameter containing:
#  tensor([[ 0.1838,  0.0701, -0.0666,  ...,  0.0383,  0.0794,  0.0303],
#          [-0.0704, -0.1833,  0.0195,  ...,  0.0240, -0.0236, -0.0268],
#          [ 0.0611,  0.0905,  0.0821,  ..., -0.0012,  0.0033, -0.1726],
#          ...,
#          [-0.0825, -0.1240, -0.2331,  ...,  0.0787, -0.1069, -0.0411],
#          [ 0.0255,  0.0341,  0.0112,  ..., -0.1393, -0.1111,  0.1156],
#          [ 0.0272, -0.0715, -0.0265,  ..., -0.1309,  0.0715, -0.0675]],
#         device='cuda:0'),
#  Parameter containing:
#  tensor([ 0.2017, -0.0947, -0.0777,  0.2626, -0.0299, -0.2046, -0.1396,  0.0172,
#          -0.0107,  0.1204,  0.0610, -0.0932,  0.1754, -0.0710, -0.1304, -0.1146,
#          -0.1816,  0.0137, -0.0799, -0.1844, -0.1397,  0.0049, -0.0247,  0.0244,
#           0.1422,  0.0100, -0.0648, -0.0542, -0.1179, -0.1503, -0.0497,  0.1020,
#           0.0408,  0.2507, -0.0249,  0.0182, -0.0721, -0.0215, -0.0260, -0.0302,
#           0.0697,  0.1838,  0.1517, -0.0421, -0.0515, -0.0052, -0.0776,  0.0180,
#          -0.0331, -0.2055,  0.0086, -0.1242,  0.0664, -0.2451, -0.1886,  0.0023,
#          -0.0150, -0.0099,  0.0754,  0.2129, -0.0628, -0.0832,  0.1831, -0.0548,
#           0.0440,  0.0805, -0.0657, -0.1207, -0.0422, -0.1846,  0.0018, -0.0814,
#           0.0916, -0.1082, -0.2165, -0.0114, -0.1752, -0.1108,  0.2353,  0.0869,
#          -0.2783, -0.0096, -0.2514,  0.1845, -0.0134, -0.0153,  0.0751, -0.1734,
#          -0.0178,  0.1831, -0.1249, -0.0415, -0.1930, -0.1449, -0.1296,  0.0849,
#           0.0146,  0.2296, -0.0373, -0.1169, -0.0096, -0.2194, -0.0590, -0.0620,
#          -0.0905, -0.1241, -0.0222, -0.0922, -0.1572, -0.0580, -0.0048,  0.3197,
#           0.1063,  0.0293,  0.0435,  0.2935, -0.0730, -0.2432,  0.1481,  0.2196,
#           0.0532,  0.0108, -0.0626, -0.0398,  0.0144, -0.1683, -0.2463, -0.0560],
#         device='cuda:0'),
#  Parameter containing:
#  tensor
#           0.1624, -0.0400,  0.0439,  0.0049,  0.0140, -0.0939,  0.0900,  0.0561,
#          -0.0826, -0.0025,  0.0299,  0.0297,  0.0618, -0.0839, -0.0759,  0.0366,
#           0.0683,  0.1208, -0.0802,  0.1871,  0.1804,  0.2623, -0.0678, -0.1130,
#           0.0076, -0.1445,  0.0094, -0.0375,  0.0076,  0.1226,  0.1640, -0.1529,
#          -0.0102,  0.0818, -0.1049, -0.1021,  0.1042,  0.0986,  0.1246,  0.0598,
#          -0.0692, -0.1077, -0.1153,  0.0343,  0.0954, -0.0909,  0.1083, -0.1705,
#          -0.0725,  0.2098, -0.2146, -0.1867,  0.2316, -0.1038, -0.1070, -0.1412,
#          -0.2097,  0.1363,  0.0566,  0.0309, -0.0627, -0.1755,  0.0743,  0.2129,
#          -0.0793, -0.1371, -0.0287,  0.2464,  0.1469,  0.1132, -0.0344, -0.1722,
#          -0.1575, -0.0474, -0.0798,  0.1205, -0.0588, -0.0093,  0.0051, -0.0780,
#           0.1350,  0.2492,  0.0139, -0.1652, -0.0573,  0.1013,  0.0045, -0.0223,
#           0.2291, -0.0349,  0.1414,  0.0033, -0.2003,  0.0362,  0.0901, -0.0667],
#         device='cuda:0'),
#  Parameter containing:
#  tensor([[-0.0072,  0.0723,  0.0448,  ...,  0.1505,  0.0383, -0.0306],
#          [-0.2320, -0.0668, -0.0872,  ...,  0.0946, -0.0359,  0.0622],
#          [-0.1608, -0.0663, -0.0764,  ...,  0.0925, -0.1036,  0.0323],
#          ...,
#          [-0.2001, -0.0577, -0.0646,  ...,  0.0362,  0.0128, -0.0423],
#          [ 0.0600,  0.0800, -0.0587,  ...,  0.1060,  0.0232,  0.0465],
#          [-0.0814,  0.0197,  0.0298,  ..., -0.0249, -0.0386, -0.0396]],
#         device='cuda:0'),
#  Parameter containing:
#  tensor([ 0.1634,  0.0139, -0.0450, -0.1750, -0.1473,  0.0944,  0.0166,  0.0331,
#           0.1662,  0.1581, -0.1108, -0.0662,  0.1110,  0.2062,  0.0405, -0.0276,
#          -0.1182,  0.0799, -0.0332, -0.0334, -0.1060, -0.3344, -0.0367, -0.0789,
#           0.1451,  0.0788, -0.0461,  0.1528, -0.0906, -0.1476, -0.1340,  0.1589,
#           0.1812,  0.0343, -0.0031, -0.1601, -0.1124, -0.0324, -0.1088, -0.1675,
#          -0.0767,  0.0967,  0.0364, -0.1045, -0.1035,  0.0762,  0.0969, -0.1187,
#          -0.0101,  0.0611,  0.0168,  0.1941, -0.0884, -0.1002, -0.1167,  0.1895,
#           0.1955, -0.0854,  0.0635, -0.1821, -0.1280, -0.0657,  0.1022,  0.2605,
#          -0.0045, -0.0882,  0.1219,  0.1090, -0.0335,  0.2174, -0.0476, -0.0668,
#           0.1807,  0.1122,  0.0683, -0.0118,  0.0883,  0.1481,  0.1349, -0.0010,
#          -0.1062,  0.1668,  0.2140, -0.1130, -0.0799, -0.1784, -0.0939, -0.0504,
#          -0.0246,  0.2133,  0.0222, -0.0700,  0.0440,  0.1527,  0.1963,  0.1660,
#  Parameter containing:
#  tensor([0.0314], device='cuda:0')]

# %%
training_settings_mix = {}    

train_base_dataset = utils.preprocessing.Dataset(source_file + "_train.npy", 0)
valid_base_dataset = utils.preprocessing.Dataset(source_file + "_val.npy", 0)

train_target_dataset = utils.preprocessing.Dataset(target_file + "_train.npy", 1)
valid_target_dataset = utils.preprocessing.Dataset(target_file + "_val.npy", 1)

training_settings_mix.update({
    "source_file": source_file,
    "target_file": target_file,
    "t0": t0,
    "t1": t1
})

# %%
train_base_dataset.process(normalize_weights=True)
valid_base_dataset.process(normalize_weights=True)

train_target_dataset.process(normalize_weights=True)
valid_target_dataset.process(normalize_weights=True)
# Out:
# tensor(0.0164)

# %%
train_generator_data = utils.preprocessing.CombinedDataset(train_base_dataset, train_target_dataset)
valid_generator_data = utils.preprocessing.CombinedDataset(valid_base_dataset, valid_target_dataset)

# %%
X_scaler, train_weight_norm = utils.preprocessing.get_scaling(train_generator_data)
_, valid_weight_norm = utils.preprocessing.get_scaling(valid_generator_data)
print(train_weight_norm, valid_weight_norm, train_weight_norm/valid_weight_norm)
# Out:
# 100%|██████████| 1517/1517 [00:08<00:00, 175.42it/s]
# 100%|██████████| 350/350 [00:01<00:00, 178.37it/s]
# tensor(1.) tensor(1.0000) tensor(1.0000)

# %%
random_seed = 0

batch_size = int(2**9)
torch.manual_seed(random_seed)

train_loader = DataLoader(train_generator_data, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_generator_data, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Save the plain SMM model

# %%
SAVE_SMM = False

if SAVE_SMM is True:
    SMM_model = utils.models.SingleMixtureClassifier(subdensity_model_paths, which_mixture=1, t0=t0, t1=t1, fine_tune=False).to(DEVICE)
    SMM_model.initialize(coefficient_init)
    model_path = osp.join("models/classifier{}_SMM".format(TEST_NUM))
    model_metadata = utils.train.get_model_metadata(training_settings_mix, SMM_model, X_scaler, train_weight_norm)
    utils.train.save_model_data(SMM_model, model_metadata, name=model_path, save_onnx=False, device=DEVICE)

# %% [markdown]
# ## Now train the others

# %%
learning_rate = 1e-4
optimizer = torch.optim.Adam(mix_model.parameters(), lr=learning_rate)

TEST_NUM = ""

if FINE_TUNE is False:
    model_path = osp.join("models/classifier{}_SMMc_qdre_batch{}".format(TEST_NUM, batch_size))
else:
    model_path = osp.join("models/classifier{}_SMMr_qdre_batch{}".format(TEST_NUM, batch_size))

# %%
n_epochs = 300
stale_epochs = 0
best_valid_loss = 99999
patience = 10
max_num_batches = int(int(1e4) / batch_size)
t = tqdm(range(0, n_epochs))

training_losses = [utils.train.test(
        mix_model,
        train_loader,
        weight_norm=train_weight_norm,
        loss='qdre',
        SMM=True,
        t0=t0,
        t1=t1,
        device=DEVICE,
        max_num_batches=max_num_batches,
        progress_bar=False,
        leave=False
    )[0],]
validation_losses = [utils.train.test(
        mix_model,
        valid_loader,
        weight_norm=valid_weight_norm,
        loss='qdre',
        SMM=True,
        t0=t0,
        t1=t1,
        device=DEVICE,
        progress_bar=False,
        leave=False
    )[0],]

for epoch in t:
    loss = utils.train.train(
        mix_model,
        optimizer,
        train_loader,
        weight_norm=train_weight_norm,
        max_num_batches=max_num_batches,
        loss='qdre',
        SMM=True,
        t0=t0,
        t1=t1,
        device=DEVICE,
        progress_bar=False,
        leave=bool(epoch == n_epochs - 1),
    )
    #loss -= optimal_train_loss
    training_losses.append(loss[0])

    valid_loss = utils.train.test(
        mix_model,
        valid_loader,
        weight_norm=valid_weight_norm,
        loss='qdre',
        SMM=True,
        t0=t0,
        t1=t1,
        device=DEVICE,
        progress_bar=False,
        leave=bool(epoch == n_epochs - 1),
    )
    #valid_loss -= optimal_valid_loss
    validation_losses.append(valid_loss[0])
    print("Epoch: {:02d}, Training Loss:   {:.4f}".format(epoch, loss[1]))
    print("           Validation Loss: {:.4f}".format(valid_loss[1]))

    if valid_loss[1] < best_valid_loss and np.abs((loss[1] - valid_loss[1]) / loss[1]) < 0.2: # Don't allow large fluctuations
        best_valid_loss = valid_loss[1]
        print("New best model with parameters:", mix_model.coefficients)
        training_settings_mix.update({
            "n_epochs": epoch+1,
            "training_losses": training_losses,
            "validation_losses": validation_losses
        })
        model_metadata = utils.train.get_model_metadata(training_settings_mix, mix_model, X_scaler, train_weight_norm)
        utils.train.save_model_data(mix_model, model_metadata, name=model_path, save_onnx=False, device=DEVICE)
        print("New best model saved to: {}.zip".format(model_path))
        stale_epochs = 0
    else:
        print("Stale epoch")
        stale_epochs += 1
    if stale_epochs >= patience:
        print("Early stopping after %i stale epochs" % patience)
        break
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch: 00, Training Loss:   0.8251
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2677199840545654)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 01, Training Loss:   0.7951
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2683625221252441)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 02, Training Loss:   0.7885
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2695709466934204)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 03, Training Loss:   0.7934
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2708207368850708)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 04, Training Loss:   0.7987
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2713778018951416)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 05, Training Loss:   0.8092
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2720389366149902)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 06, Training Loss:   0.8024
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2726653814315796)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 07, Training Loss:   0.7884
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.273531198501587)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 08, Training Loss:   0.8115
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2746630907058716)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 09, Training Loss:   0.7947
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2755849361419678)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 10, Training Loss:   0.7947
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2761515378952026)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 11, Training Loss:   0.7976
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2764631509780884)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 12, Training Loss:   0.8009
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2770267724990845)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 13, Training Loss:   0.7992
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.277740478515625)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 14, Training Loss:   0.8069
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2779767513275146)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 15, Training Loss:   0.8090
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.278341293334961)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 16, Training Loss:   0.8067
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2791588306427002)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 17, Training Loss:   0.8081
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2793043851852417)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 18, Training Loss:   0.8054
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2796376943588257)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 19, Training Loss:   0.8054
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2800488471984863)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 20, Training Loss:   0.8036
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2806086540222168)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 21, Training Loss:   0.8052
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2811026573181152)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 22, Training Loss:   0.8135
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.281518816947937)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 23, Training Loss:   0.8049
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2818512916564941)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 24, Training Loss:   0.8093
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.282030701637268)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 25, Training Loss:   0.8121
#            Validation Loss: 0.8472
# Stale epoch
# Epoch: 26, Training Loss:   0.7917
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2821316719055176)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 27, Training Loss:   0.7942
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2831534147262573)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 28, Training Loss:   0.7973
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.283939242362976)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 29, Training Loss:   0.8020
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2847615480422974)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 30, Training Loss:   0.8026
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2854459285736084)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 31, Training Loss:   0.7992
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2858598232269287)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 32, Training Loss:   0.8063
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2861632108688354)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 33, Training Loss:   0.8064
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.286454200744629)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 34, Training Loss:   0.7986
#            Validation Loss: 0.8472
# New best model with parameters: (1.0, 1.2871553897857666)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 35, Training Loss:   0.7985
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.288003921508789)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 36, Training Loss:   0.8045
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2882803678512573)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 37, Training Loss:   0.8103
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.28852117061615)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 38, Training Loss:   0.7997
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2888649702072144)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 39, Training Loss:   0.7941
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.289360523223877)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 40, Training Loss:   0.8153
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.289565086364746)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 41, Training Loss:   0.8202
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 42, Training Loss:   0.7946
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 43, Training Loss:   0.7975
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2898694276809692)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 44, Training Loss:   0.8009
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.290225625038147)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 45, Training Loss:   0.7951
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2904554605484009)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 46, Training Loss:   0.8039
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2913213968276978)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 47, Training Loss:   0.7973
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2921404838562012)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 48, Training Loss:   0.8103
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2925101518630981)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 49, Training Loss:   0.8035
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2929354906082153)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 50, Training Loss:   0.7927
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2933034896850586)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 51, Training Loss:   0.8071
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2934690713882446)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 52, Training Loss:   0.7877
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2941863536834717)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 53, Training Loss:   0.8085
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2943814992904663)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 54, Training Loss:   0.8098
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.294407844543457)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 55, Training Loss:   0.7962
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2944990396499634)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 56, Training Loss:   0.8165
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 57, Training Loss:   0.7937
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 58, Training Loss:   0.7949
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2951970100402832)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 59, Training Loss:   0.7937
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2956128120422363)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 60, Training Loss:   0.7939
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2960385084152222)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 61, Training Loss:   0.8016
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 62, Training Loss:   0.8063
#            Validation Loss: nan
# Stale epoch
# Epoch: 63, Training Loss:   0.8210
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2960678339004517)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 64, Training Loss:   0.8054
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 65, Training Loss:   0.8008
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2962881326675415)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 66, Training Loss:   0.7988
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2971296310424805)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 67, Training Loss:   0.7983
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.297293782234192)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 68, Training Loss:   0.8048
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2975302934646606)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 69, Training Loss:   0.7961
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2977701425552368)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 70, Training Loss:   0.8009
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2980767488479614)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 71, Training Loss:   0.8045
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2984637022018433)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 72, Training Loss:   0.8058
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 73, Training Loss:   0.8136
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2984689474105835)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 74, Training Loss:   0.7935
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2990195751190186)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 75, Training Loss:   0.8093
#            Validation Loss: 0.8471
# New best model with parameters: (1.0, 1.2990556955337524)
# New best model saved to: models/classifier_SMMc_qdre_batch512.zip
# Epoch: 76, Training Loss:   0.7999
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 77, Training Loss:   0.7958
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 78, Training Loss:   0.8125
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 79, Training Loss:   0.8025
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 80, Training Loss:   0.8250
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 81, Training Loss:   0.8111
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 82, Training Loss:   0.8063
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 83, Training Loss:   0.7964
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 84, Training Loss:   0.8027
#            Validation Loss: 0.8471
# Stale epoch
# Epoch: 85, Training Loss:   0.8127
#            Validation Loss: 0.8471
# Stale epoch
# Early stopping after 10 stale epochs

# %% [markdown]
# ## Look at the loss curves

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10, 8)

starting_epoch = 1
training_loss_per_epoch = np.array(training_losses[starting_epoch:]).mean(axis=1)
training_std_per_epoch = np.array(training_losses[starting_epoch:]).std(axis=1)

validation_loss_per_epoch = np.array(validation_losses[starting_epoch:]).mean(axis=1)
validation_std_per_epoch = np.array(validation_losses[starting_epoch:]).std(axis=1)

training_lower_bar = training_loss_per_epoch - training_std_per_epoch
training_upper_bar = training_loss_per_epoch + training_std_per_epoch

validation_lower_bar = validation_loss_per_epoch - validation_std_per_epoch
validation_upper_bar = validation_loss_per_epoch + validation_std_per_epoch


t1 = np.arange(len(training_loss_per_epoch))
t2 = np.arange(len(validation_loss_per_epoch))
ax.plot(t1, training_loss_per_epoch, '-', label="Training loss", c='tab:blue')
ax.fill_between(t1, training_lower_bar, training_upper_bar, color='tab:blue', alpha=0.30)

ax.plot(t2, validation_loss_per_epoch, '-', label="Validation loss", c='tab:orange')
ax.fill_between(t2, validation_lower_bar, validation_upper_bar, color='tab:orange', alpha=0.30)

#ax.set_xscale('log')
ax.legend()
ax.set_xlabel("Epoch")
ax.set_ylabel("PARE Loss")
# Out:
# Text(0, 0.5, 'PARE Loss')
