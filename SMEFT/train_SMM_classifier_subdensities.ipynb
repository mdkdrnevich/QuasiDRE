# %%
import sys
sys.path.append('../')
import os
import os.path as osp

import torch
from torch.utils.data import DataLoader
import numpy as np
from tqdm.notebook import tqdm

import utils
import vector

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#DEVICE = 'cpu'
print(DEVICE)
# Out:
# /home/mdrnevich/test/QuasiDRE/SMEFT/../utils/__init__.py:5: UserWarning: The recommended fonts to use plothist were not found. You can install them by typing 'install_latin_modern_fonts' in your terminal. If it still does not work, please check the documentation at https://plothist.readthedocs.io/en/latest/usage/font_installation.html
#   from . import plotting
# cuda:0

# %%
DATA_DIR = "./data/"
SAVE = True

source_file = osp.join(DATA_DIR, "SMEFT_SM_combined_tuple")
target_file = osp.join(DATA_DIR, "SMEFT_EFT_combined_tuple")

if SAVE:
    for dataset in ["train", "val", "test"]:
        data_arrays_pos = []
        data_arrays_neg = []
        
        arr = np.load(source_file + "_" + dataset + ".npy")
        data_arrays_pos.append(arr[arr[:,-1] >= 0])
        data_arrays_neg.append(arr[arr[:,-1] < 0])

        arr = np.load(target_file + "_" + dataset + ".npy")
        data_arrays_pos.append(arr[arr[:,-1] >= 0])
        data_arrays_neg.append(arr[arr[:,-1] < 0])

        # Save the positively weighted datasets
        np.save(source_file + "_positives_" + dataset + ".npy", data_arrays_pos[0])
        np.save(target_file + "_positives_" + dataset + ".npy", data_arrays_pos[1])

        # Save the negatively weighted datasets
        np.save(source_file + "_negatives_" + dataset + ".npy", data_arrays_neg[0])
        np.save(target_file + "_negatives_" + dataset + ".npy", data_arrays_neg[1])

        del data_arrays_pos, data_arrays_neg

# %%
source_positive_file = source_file + "_positives"
source_negative_file = source_file + "_negatives"
target_positive_file = target_file + "_positives"
target_negative_file = target_file + "_negatives"

files = [source_positive_file, source_negative_file, target_positive_file, target_negative_file]
submodel_names = np.array(["Pos", "Neg", "Pos", "Neg"])

train_datasizes = []
val_datasizes = []
test_datasizes = []
for f in files:
    train_datasizes.append(np.load(f + "_train.npy").shape[0])
    val_datasizes.append(np.load(f + "_val.npy").shape[0])
    test_datasizes.append(np.load(f + "_test.npy").shape[0])

train_datasizes = np.array(train_datasizes)
val_datasizes = np.array(val_datasizes)
test_datasizes = np.array(test_datasizes)

train_datasizes, val_datasizes, test_datasizes
# Out:
# (array([776369,      0, 641157, 135212]),
#  array([179162,      0, 148045,  31117]),
#  array([238883,      0, 197103,  41780]))

# %% [markdown]
# ### There are no negatives in the source dataset, so only use two subdensities

# %%
combos = [np.array((0,2)), #++
          np.array((0,3))] #+-

NUM_MODELS = 2

# %% [markdown]
# ## Initiate the datasets

# %%
training_settings = [{} for _ in range(NUM_MODELS)]

train_generator_datas = []
valid_generator_datas = []
test_generator_datas = []

for i in range(NUM_MODELS):
    sub_source_file = files[combos[i][0]]
    sub_target_file = files[combos[i][1]]
    min_datasizes = (train_datasizes[combos[i]].min(), val_datasizes[combos[i]].min(), test_datasizes[combos[i]].min())
        
    print(min_datasizes)
    training_settings[i].update({
        "source_file": sub_source_file,
        "target_file": sub_target_file,
        "n_train": int(min_datasizes[0]),
        "n_val": int(min_datasizes[1]),
        "n_test": int(min_datasizes[2])
    })
    print(sub_source_file, sub_target_file)


    train_base_dataset = utils.preprocessing.Dataset(sub_source_file + "_train.npy", 0,
                                                     stop_event=training_settings[i]["n_train"])
    valid_base_dataset = utils.preprocessing.Dataset(files[combos[i][0]] + "_val.npy", 0,
                                                     stop_event=training_settings[i]["n_val"])

    train_target_dataset = utils.preprocessing.Dataset(sub_target_file + "_train.npy", 1,
                                                     stop_event=training_settings[i]["n_train"])
    valid_target_dataset = utils.preprocessing.Dataset(files[combos[i][1]] + "_val.npy", 1,
                                                     stop_event=training_settings[i]["n_val"])


    source_weight_norm = train_base_dataset.process(normalize_weights=True)
    source_valid_weight_norm = valid_base_dataset.process(normalize_weights=True)
    
    target_weight_norm = train_target_dataset.process(normalize_weights=True)
    target_valid_weight_norm = valid_target_dataset.process(normalize_weights=True)

    train_generator_datas.append(utils.preprocessing.CombinedDataset(train_base_dataset, train_target_dataset))
    valid_generator_datas.append(utils.preprocessing.CombinedDataset(valid_base_dataset, valid_target_dataset))
# Out:
# (np.int64(641157), np.int64(148045), np.int64(197103))
# ./data/SMEFT_SM_combined_tuple_positives ./data/SMEFT_EFT_combined_tuple_positives
# (np.int64(135212), np.int64(31117), np.int64(41780))
# ./data/SMEFT_SM_combined_tuple_positives ./data/SMEFT_EFT_combined_tuple_negatives

# %% [markdown]
# ## Do some data preprocessing for standardized inputs and weights

# %%
X_scalers, train_weight_norms = list(zip(*[utils.preprocessing.get_scaling(train_generator_data) for train_generator_data in train_generator_datas]))
_, valid_weight_norms = list(zip(*[utils.preprocessing.get_scaling(valid_generator_data) for valid_generator_data in valid_generator_datas]))
print(train_weight_norms, valid_weight_norms)
# Out:
# 100%|██████████| 1253/1253 [00:07<00:00, 176.86it/s]
# 100%|██████████| 265/265 [00:01<00:00, 252.26it/s]
# 100%|██████████| 290/290 [00:01<00:00, 253.77it/s]
# 100%|██████████| 61/61 [00:00<00:00, 185.64it/s]
# (tensor(1.0000), tensor(1.0000)) (tensor(1.0000), tensor(1.0000))

# %% [markdown]
# ## Prepare the data for training

# %%
random_seed = 0

torch.manual_seed(random_seed)
batch_sizes = [int(2**6), int(2**6)]
[ts.update({
    "batch_size": batch_sizes[i],
    "random_seed": random_seed
}) for i, ts in enumerate(training_settings)]

train_loaders = [DataLoader(train_generator_data, batch_size=batch_sizes[i], shuffle=True) for i, train_generator_data in enumerate(train_generator_datas)]
valid_loaders = [DataLoader(valid_generator_data, batch_size=batch_sizes[i], shuffle=False) for i, valid_generator_data in enumerate(valid_generator_datas)]

# %% [markdown]
# ## Construct the model

# %%
inputs = 16
hidden_nodes = [128, 128, 128]
outputs = 1

models = [utils.models.Classifier(inputs, hidden_nodes, outputs).to(DEVICE) for _ in range(NUM_MODELS)]
print(models)
print("----------")

#model = model.to(DEVICE)

learning_rate = 1e-3
optimizers = [torch.optim.Adam(model.parameters(), lr=learning_rate) for model in models]

[ts.update({
    "learning_rate": learning_rate,
    "optimizer": "Adam"
}) for ts in training_settings]
# Out:
# [Classifier(
#   (model): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# ), Classifier(
#   (model): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )]
# ----------
# [None, None]

# %%
SAVE_DIR = "./models/"
if not osp.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %% [markdown]
# ## Perform the training

# %%
for i in range(NUM_MODELS):
    modname = "classifier_subdensity_{}_batch{}".format(''.join(submodel_names[combos[i]]), batch_sizes[i])
    model = models[i]
    optimizer = optimizers[i]
    X_scaler = X_scalers[i]
    train_weight_norm = train_weight_norms[i]
    valid_weight_norm = valid_weight_norms[i]
    train_loader = train_loaders[i]
    valid_loader = valid_loaders[i]
    lossfunction = 'bce' #'bce', 'sqrt'
    regularization = 0 #1e-5 #0.01
    
    n_epochs = 1500
    stale_epochs = 0
    best_valid_loss = 99999
    patience = [15, 15]
    max_num_batches = int(int(2e4) / batch_sizes[i])
    t = tqdm(range(0, n_epochs))
    
    training_losses = [utils.train.test(
            model,
            train_loader,
            X_scaler,
            weight_norm=train_weight_norm,
            max_num_batches=max_num_batches,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=False
        )[0],]
    validation_losses = [utils.train.test(
            model,
            valid_loader,
            X_scaler,
            weight_norm=valid_weight_norm,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=False
        )[0],]
    
    
    for epoch in t:
        loss = utils.train.train(
            model,
            optimizer,
            train_loader,
            X_scaler,
            weight_norm=train_weight_norm,
            max_num_batches=max_num_batches,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=bool(epoch == n_epochs - 1),
        )
        #loss -= optimal_train_loss
        training_losses.append(loss[0])
    
        valid_loss = utils.train.test(
            model,
            valid_loader,
            X_scaler,
            weight_norm=valid_weight_norm,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=bool(epoch == n_epochs - 1),
        )
        #valid_loss -= optimal_valid_loss
        validation_losses.append(valid_loss[0])
        print("Epoch: {:02d}, Training Loss:   {:.4f}".format(epoch, loss[1]))
        print("           Validation Loss: {:.4f}".format(valid_loss[1]))
    
        if valid_loss[1] < best_valid_loss:
            best_valid_loss = valid_loss[1]
            training_settings[i].update({
                "n_epochs": epoch+1,
                "training_losses": training_losses,
                "validation_losses": validation_losses
            })
            model_metadata = utils.train.get_model_metadata(training_settings[i], model, X_scaler, train_weight_norm)
            utils.train.save_model_data(model, model_metadata, savedir=SAVE_DIR, name=modname, save_onnx=False, device=DEVICE)
            print("New best model saved to: {}.zip".format(osp.join(SAVE_DIR, modname)))
            stale_epochs = 0
        else:
            print("Stale epoch")
            stale_epochs += 1
        if stale_epochs >= patience[i]:
            print("Early stopping after %i stale epochs" % patience[i])
            break
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch: 00, Training Loss:   0.6430
#            Validation Loss: 0.6252
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 01, Training Loss:   0.6249
#            Validation Loss: 0.6175
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 02, Training Loss:   0.6120
#            Validation Loss: 0.6170
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 03, Training Loss:   0.6089
#            Validation Loss: 0.6068
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 04, Training Loss:   0.6032
#            Validation Loss: 0.6059
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 05, Training Loss:   0.6055
#            Validation Loss: 0.6087
# Stale epoch
# Epoch: 06, Training Loss:   0.6047
#            Validation Loss: 0.6035
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 07, Training Loss:   0.6018
#            Validation Loss: 0.6040
# Stale epoch
# Epoch: 08, Training Loss:   0.5978
#            Validation Loss: 0.6011
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 09, Training Loss:   0.6000
#            Validation Loss: 0.5998
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 10, Training Loss:   0.5997
#            Validation Loss: 0.6018
# Stale epoch
# Epoch: 11, Training Loss:   0.6031
#            Validation Loss: 0.6006
# Stale epoch
# Epoch: 12, Training Loss:   0.5970
#            Validation Loss: 0.5980
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 13, Training Loss:   0.5953
#            Validation Loss: 0.6016
# Stale epoch
# Epoch: 14, Training Loss:   0.5983
#            Validation Loss: 0.5993
# Stale epoch
# Epoch: 15, Training Loss:   0.5968
#            Validation Loss: 0.5975
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 16, Training Loss:   0.5953
#            Validation Loss: 0.5986
# Stale epoch
# Epoch: 17, Training Loss:   0.5956
#            Validation Loss: 0.5996
# Stale epoch
# Epoch: 18, Training Loss:   0.5984
#            Validation Loss: 0.5969
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 19, Training Loss:   0.5957
#            Validation Loss: 0.5981
# Stale epoch
# Epoch: 20, Training Loss:   0.5943
#            Validation Loss: 0.5972
# Stale epoch
# Epoch: 21, Training Loss:   0.5947
#            Validation Loss: 0.5981
# Stale epoch
# Epoch: 22, Training Loss:   0.5956
#            Validation Loss: 0.5955
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 23, Training Loss:   0.5924
#            Validation Loss: 0.5964
# Stale epoch
# Epoch: 24, Training Loss:   0.5970
#            Validation Loss: 0.5956
# Stale epoch
# Epoch: 25, Training Loss:   0.5973
#            Validation Loss: 0.5988
# Stale epoch
# Epoch: 26, Training Loss:   0.5962
#            Validation Loss: 0.5969
# Stale epoch
# Epoch: 27, Training Loss:   0.5927
#            Validation Loss: 0.5947
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 28, Training Loss:   0.5963
#            Validation Loss: 0.5960
# Stale epoch
# Epoch: 29, Training Loss:   0.5943
#            Validation Loss: 0.5957
# Stale epoch
# Epoch: 30, Training Loss:   0.5912
#            Validation Loss: 0.5976
# Stale epoch
# Epoch: 31, Training Loss:   0.5920
#            Validation Loss: 0.5950
# Stale epoch
# Epoch: 32, Training Loss:   0.5872
#            Validation Loss: 0.5974
# Stale epoch
# Epoch: 33, Training Loss:   0.5880
#            Validation Loss: 0.5947
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 34, Training Loss:   0.5933
#            Validation Loss: 0.5958
# Stale epoch
# Epoch: 35, Training Loss:   0.5929
#            Validation Loss: 0.5972
# Stale epoch
# Epoch: 36, Training Loss:   0.5925
#            Validation Loss: 0.5951
# Stale epoch
# Epoch: 37, Training Loss:   0.5914
#            Validation Loss: 0.5955
# Stale epoch
# Epoch: 38, Training Loss:   0.5955
#            Validation Loss: 0.5946
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 39, Training Loss:   0.5903
#            Validation Loss: 0.5936
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 40, Training Loss:   0.5932
#            Validation Loss: 0.5944
# Stale epoch
# Epoch: 41, Training Loss:   0.5922
#            Validation Loss: 0.5937
# Stale epoch
# Epoch: 42, Training Loss:   0.5908
#            Validation Loss: 0.5933
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 43, Training Loss:   0.5950
#            Validation Loss: 0.5960
# Stale epoch
# Epoch: 44, Training Loss:   0.5947
#            Validation Loss: 0.5934
# Stale epoch
# Epoch: 45, Training Loss:   0.5914
#            Validation Loss: 0.5938
# Stale epoch
# Epoch: 46, Training Loss:   0.5939
#            Validation Loss: 0.5945
# Stale epoch
# Epoch: 47, Training Loss:   0.5894
#            Validation Loss: 0.5950
# Stale epoch
# Epoch: 48, Training Loss:   0.5893
#            Validation Loss: 0.5936
# Stale epoch
# Epoch: 49, Training Loss:   0.5932
#            Validation Loss: 0.5950
# Stale epoch
# Epoch: 50, Training Loss:   0.5977
#            Validation Loss: 0.5939
# Stale epoch
# Epoch: 51, Training Loss:   0.5937
#            Validation Loss: 0.5937
# Stale epoch
# Epoch: 52, Training Loss:   0.5963
#            Validation Loss: 0.5949
# Stale epoch
# Epoch: 53, Training Loss:   0.5928
#            Validation Loss: 0.5947
# Stale epoch
# Epoch: 54, Training Loss:   0.5900
#            Validation Loss: 0.5928
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 55, Training Loss:   0.5916
#            Validation Loss: 0.5937
# Stale epoch
# Epoch: 56, Training Loss:   0.5960
#            Validation Loss: 0.5942
# Stale epoch
# Epoch: 57, Training Loss:   0.5900
#            Validation Loss: 0.5926
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 58, Training Loss:   0.5887
#            Validation Loss: 0.5950
# Stale epoch
# Epoch: 59, Training Loss:   0.5933
#            Validation Loss: 0.5926
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 60, Training Loss:   0.5870
#            Validation Loss: 0.5948
# Stale epoch
# Epoch: 61, Training Loss:   0.5871
#            Validation Loss: 0.5936
# Stale epoch
# Epoch: 62, Training Loss:   0.5930
#            Validation Loss: 0.5949
# Stale epoch
# Epoch: 63, Training Loss:   0.5910
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 64, Training Loss:   0.5844
#            Validation Loss: 0.5947
# Stale epoch
# Epoch: 65, Training Loss:   0.5860
#            Validation Loss: 0.5946
# Stale epoch
# Epoch: 66, Training Loss:   0.5874
#            Validation Loss: 0.5934
# Stale epoch
# Epoch: 67, Training Loss:   0.5944
#            Validation Loss: 0.5929
# Stale epoch
# Epoch: 68, Training Loss:   0.5873
#            Validation Loss: 0.5926
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 69, Training Loss:   0.5918
#            Validation Loss: 0.5928
# Stale epoch
# Epoch: 70, Training Loss:   0.5928
#            Validation Loss: 0.5944
# Stale epoch
# Epoch: 71, Training Loss:   0.5862
#            Validation Loss: 0.5940
# Stale epoch
# Epoch: 72, Training Loss:   0.5876
#            Validation Loss: 0.5928
# Stale epoch
# Epoch: 73, Training Loss:   0.5882
#            Validation Loss: 0.5923
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 74, Training Loss:   0.5848
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 75, Training Loss:   0.5912
#            Validation Loss: 0.5919
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 76, Training Loss:   0.5902
#            Validation Loss: 0.5921
# Stale epoch
# Epoch: 77, Training Loss:   0.5901
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 78, Training Loss:   0.5878
#            Validation Loss: 0.5920
# Stale epoch
# Epoch: 79, Training Loss:   0.5936
#            Validation Loss: 0.5918
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 80, Training Loss:   0.5881
#            Validation Loss: 0.5925
# Stale epoch
# Epoch: 81, Training Loss:   0.5904
#            Validation Loss: 0.5917
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 82, Training Loss:   0.5886
#            Validation Loss: 0.5921
# Stale epoch
# Epoch: 83, Training Loss:   0.5925
#            Validation Loss: 0.5935
# Stale epoch
# Epoch: 84, Training Loss:   0.5874
#            Validation Loss: 0.5940
# Stale epoch
# Epoch: 85, Training Loss:   0.5904
#            Validation Loss: 0.5919
# Stale epoch
# Epoch: 86, Training Loss:   0.5871
#            Validation Loss: 0.5937
# Stale epoch
# Epoch: 87, Training Loss:   0.5886
#            Validation Loss: 0.5925
# Stale epoch
# Epoch: 88, Training Loss:   0.5903
#            Validation Loss: 0.5911
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 89, Training Loss:   0.5868
#            Validation Loss: 0.5905
# New best model saved to: ./models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 90, Training Loss:   0.5893
#            Validation Loss: 0.5913
# Stale epoch
# Epoch: 91, Training Loss:   0.5899
#            Validation Loss: 0.5917
# Stale epoch
# Epoch: 92, Training Loss:   0.5884
#            Validation Loss: 0.5913
# Stale epoch
# Epoch: 93, Training Loss:   0.5890
#            Validation Loss: 0.5915
# Stale epoch
# Epoch: 94, Training Loss:   0.5874
#            Validation Loss: 0.5921
# Stale epoch
# Epoch: 95, Training Loss:   0.5907
#            Validation Loss: 0.5918
# Stale epoch
# Epoch: 96, Training Loss:   0.5922
#            Validation Loss: 0.5938
# Stale epoch
# Epoch: 97, Training Loss:   0.5874
#            Validation Loss: 0.5914
# Stale epoch
# Epoch: 98, Training Loss:   0.5867
#            Validation Loss: 0.5926
# Stale epoch
# Epoch: 99, Training Loss:   0.5906
#            Validation Loss: 0.5917
# Stale epoch
# Epoch: 100, Training Loss:   0.5859
#            Validation Loss: 0.5919
# Stale epoch
# Epoch: 101, Training Loss:   0.5915
#            Validation Loss: 0.5930
# Stale epoch
# Epoch: 102, Training Loss:   0.5868
#            Validation Loss: 0.5912
# Stale epoch
# Epoch: 103, Training Loss:   0.5885
#            Validation Loss: 0.5912
# Stale epoch
# Epoch: 104, Training Loss:   0.5906
#            Validation Loss: 0.5927
# Stale epoch
# Early stopping after 15 stale epochs
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch: 00, Training Loss:   0.4054
#            Validation Loss: 0.3331
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 01, Training Loss:   0.3041
#            Validation Loss: 0.2945
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 02, Training Loss:   0.2840
#            Validation Loss: 0.2738
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 03, Training Loss:   0.2795
#            Validation Loss: 0.2714
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 04, Training Loss:   0.2622
#            Validation Loss: 0.2576
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 05, Training Loss:   0.2627
#            Validation Loss: 0.2577
# Stale epoch
# Epoch: 06, Training Loss:   0.2577
#            Validation Loss: 0.2575
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 07, Training Loss:   0.2538
#            Validation Loss: 0.2474
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 08, Training Loss:   0.2493
#            Validation Loss: 0.2483
# Stale epoch
# Epoch: 09, Training Loss:   0.2484
#            Validation Loss: 0.2529
# Stale epoch
# Epoch: 10, Training Loss:   0.2550
#            Validation Loss: 0.2538
# Stale epoch
# Epoch: 11, Training Loss:   0.2453
#            Validation Loss: 0.2447
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 12, Training Loss:   0.2430
#            Validation Loss: 0.2468
# Stale epoch
# Epoch: 13, Training Loss:   0.2407
#            Validation Loss: 0.2480
# Stale epoch
# Epoch: 14, Training Loss:   0.2404
#            Validation Loss: 0.2453
# Stale epoch
# Epoch: 15, Training Loss:   0.2458
#            Validation Loss: 0.2407
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 16, Training Loss:   0.2416
#            Validation Loss: 0.2364
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 17, Training Loss:   0.2386
#            Validation Loss: 0.2361
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 18, Training Loss:   0.2382
#            Validation Loss: 0.2449
# Stale epoch
# Epoch: 19, Training Loss:   0.2392
#            Validation Loss: 0.2374
# Stale epoch
# Epoch: 20, Training Loss:   0.2492
#            Validation Loss: 0.2410
# Stale epoch
# Epoch: 21, Training Loss:   0.2344
#            Validation Loss: 0.2383
# Stale epoch
# Epoch: 22, Training Loss:   0.2335
#            Validation Loss: 0.2326
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 23, Training Loss:   0.2344
#            Validation Loss: 0.2353
# Stale epoch
# Epoch: 24, Training Loss:   0.2343
#            Validation Loss: 0.2386
# Stale epoch
# Epoch: 25, Training Loss:   0.2316
#            Validation Loss: 0.2332
# Stale epoch
# Epoch: 26, Training Loss:   0.2364
#            Validation Loss: 0.2346
# Stale epoch
# Epoch: 27, Training Loss:   0.2386
#            Validation Loss: 0.2348
# Stale epoch
# Epoch: 28, Training Loss:   0.2310
#            Validation Loss: 0.2352
# Stale epoch
# Epoch: 29, Training Loss:   0.2271
#            Validation Loss: 0.2333
# Stale epoch
# Epoch: 30, Training Loss:   0.2328
#            Validation Loss: 0.2332
# Stale epoch
# Epoch: 31, Training Loss:   0.2317
#            Validation Loss: 0.2317
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 32, Training Loss:   0.2330
#            Validation Loss: 0.2359
# Stale epoch
# Epoch: 33, Training Loss:   0.2271
#            Validation Loss: 0.2315
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 34, Training Loss:   0.2224
#            Validation Loss: 0.2298
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 35, Training Loss:   0.2273
#            Validation Loss: 0.2268
# New best model saved to: ./models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 36, Training Loss:   0.2323
#            Validation Loss: 0.2306
# Stale epoch
# Epoch: 37, Training Loss:   0.2296
#            Validation Loss: 0.2313
# Stale epoch
# Epoch: 38, Training Loss:   0.2293
#            Validation Loss: 0.2303
# Stale epoch
# Epoch: 39, Training Loss:   0.2229
#            Validation Loss: 0.2313
# Stale epoch
# Epoch: 40, Training Loss:   0.2273
#            Validation Loss: 0.2292
# Stale epoch
# Epoch: 41, Training Loss:   0.2239
#            Validation Loss: 0.2310
# Stale epoch
# Epoch: 42, Training Loss:   0.2268
#            Validation Loss: 0.2317
# Stale epoch
# Epoch: 43, Training Loss:   0.2258
#            Validation Loss: 0.2292
# Stale epoch
# Epoch: 44, Training Loss:   0.2272
#            Validation Loss: 0.2284
# Stale epoch
# Epoch: 45, Training Loss:   0.2215
#            Validation Loss: 0.2283
# Stale epoch
# Epoch: 46, Training Loss:   0.2384
#            Validation Loss: 0.2407
# Stale epoch
# Epoch: 47, Training Loss:   0.2256
#            Validation Loss: 0.2317
# Stale epoch
# Epoch: 48, Training Loss:   0.2262
#            Validation Loss: 0.2284
# Stale epoch
# Epoch: 49, Training Loss:   0.2191
#            Validation Loss: 0.2311
# Stale epoch
# Epoch: 50, Training Loss:   0.2232
#            Validation Loss: 0.2291
# Stale epoch
# Early stopping after 15 stale epochs
