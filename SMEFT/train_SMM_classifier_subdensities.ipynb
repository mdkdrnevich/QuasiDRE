# %%
import sys
sys.path.append('../')
import os.path as osp

import torch
from torch.utils.data import DataLoader
import numpy as np
from tqdm.notebook import tqdm

import utils
import vector

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#DEVICE = 'cpu'
print(DEVICE)
# Out:
# cuda:0
# /home/mdrnevich/dev/QuasiML_paper/QuasiML/SMEFT/../utils/__init__.py:5: UserWarning: The recommended fonts to use plothist were not found. You can install them by typing 'install_latin_modern_fonts' in your terminal.
#
#   from . import plotting

# %%
DATA_NUM = ""
TEST_NUM = ""

source_file = "./data/SMEFT_SM_combined_tuple{}".format(DATA_NUM)
target_file = "./data/SMEFT_EFT_combined_tuple{}".format(DATA_NUM)
SAVE = True

if SAVE is True:
    for dataset in ["train", "val", "test"]:
        data_arrays_pos = []
        data_arrays_neg = []
        
        arr = np.load(source_file + "_" + dataset + ".npy")
        data_arrays_pos.append(arr[arr[:,-1] >= 0])
        data_arrays_neg.append(arr[arr[:,-1] < 0])

        arr = np.load(target_file + "_" + dataset + ".npy")
        data_arrays_pos.append(arr[arr[:,-1] >= 0])
        data_arrays_neg.append(arr[arr[:,-1] < 0])

        # Save the positively weighted datasets
        np.save(source_file + "_positives_" + dataset + ".npy", data_arrays_pos[0])
        np.save(target_file + "_positives_" + dataset + ".npy", data_arrays_pos[1])

        # Save the negatively weighted datasets
        np.save(source_file + "_negatives_" + dataset + ".npy", data_arrays_neg[0])
        np.save(target_file + "_negatives_" + dataset + ".npy", data_arrays_neg[1])

        del data_arrays_pos, data_arrays_neg

# %%
source_positive_file = source_file + "_positives"
source_negative_file = source_file + "_negatives"
target_positive_file = target_file + "_positives"
target_negative_file = target_file + "_negatives"

files = [source_positive_file, source_negative_file, target_positive_file, target_negative_file]
submodel_names = np.array(["Pos", "Neg", "Pos", "Neg"])

train_datasizes = []
val_datasizes = []
test_datasizes = []
for f in files:
    train_datasizes.append(np.load(f + "_train.npy").shape[0])
    val_datasizes.append(np.load(f + "_val.npy").shape[0])
    test_datasizes.append(np.load(f + "_test.npy").shape[0])

train_datasizes = np.array(train_datasizes)
val_datasizes = np.array(val_datasizes)
test_datasizes = np.array(test_datasizes)

train_datasizes, val_datasizes, test_datasizes
# Out:
# (array([776369,      0, 641189, 135180]),
#  array([179162,      0, 147880,  31282]),
#  array([238883,      0, 197236,  41647]))

# %% [markdown]
# ### There are no negatives in the source dataset, so only use two subdensities

# %%
combos = [np.array((0,2)), #++
          np.array((0,3))] #+-

NUM_MODELS = 2

# %% [markdown]
# ## Initiate the datasets

# %%
training_settings = [{} for _ in range(NUM_MODELS)]

train_generator_datas = []
valid_generator_datas = []
test_generator_datas = []

for i in range(NUM_MODELS):
    sub_source_file = files[combos[i][0]]
    sub_target_file = files[combos[i][1]]
    min_datasizes = (train_datasizes[combos[i]].min(), val_datasizes[combos[i]].min(), test_datasizes[combos[i]].min())
        
    print(min_datasizes)
    training_settings[i].update({
        "source_file": sub_source_file,
        "target_file": sub_target_file,
        "n_train": int(min_datasizes[0]),
        "n_val": int(min_datasizes[1]),
        "n_test": int(min_datasizes[2])
    })
    print(sub_source_file, sub_target_file)


    train_base_dataset = utils.preprocessing.Dataset(sub_source_file + "_train.npy", 0,
                                                     stop_event=training_settings[i]["n_train"])
    valid_base_dataset = utils.preprocessing.Dataset(files[combos[i][0]] + "_val.npy", 0,
                                                     stop_event=training_settings[i]["n_val"])

    train_target_dataset = utils.preprocessing.Dataset(sub_target_file + "_train.npy", 1,
                                                     stop_event=training_settings[i]["n_train"])
    valid_target_dataset = utils.preprocessing.Dataset(files[combos[i][1]] + "_val.npy", 1,
                                                     stop_event=training_settings[i]["n_val"])


    source_weight_norm = train_base_dataset.process(normalize_weights=True)
    source_valid_weight_norm = valid_base_dataset.process(normalize_weights=True)
    
    target_weight_norm = train_target_dataset.process(normalize_weights=True)
    target_valid_weight_norm = valid_target_dataset.process(normalize_weights=True)

    train_generator_datas.append(utils.preprocessing.CombinedDataset(train_base_dataset, train_target_dataset))
    valid_generator_datas.append(utils.preprocessing.CombinedDataset(valid_base_dataset, valid_target_dataset))
# Out:
# (641189, 147880, 197236)
# ./data/SMEFT_SM_combined_tuple_positives ./data/SMEFT_EFT_combined_tuple_positives
# (135180, 31282, 41647)
# ./data/SMEFT_SM_combined_tuple_positives ./data/SMEFT_EFT_combined_tuple_negatives

# %% [markdown]
# ## Do some data preprocessing for standardized inputs and weights

# %%
X_scalers, train_weight_norms = list(zip(*[utils.preprocessing.get_scaling(train_generator_data) for train_generator_data in train_generator_datas]))
_, valid_weight_norms = list(zip(*[utils.preprocessing.get_scaling(valid_generator_data) for valid_generator_data in valid_generator_datas]))
print(train_weight_norms, valid_weight_norms)
# Out:
# 100%|██████████| 1253/1253 [00:08<00:00, 141.26it/s]
# 100%|██████████| 265/265 [00:01<00:00, 142.63it/s]
# 100%|██████████| 289/289 [00:02<00:00, 136.05it/s]
# 100%|██████████| 62/62 [00:00<00:00, 179.62it/s]
# (tensor(1.0000), tensor(1.0000)) (tensor(1.0000), tensor(1.0000))

# %% [markdown]
# ## Prepare the data for training

# %%
random_seed = 0

torch.manual_seed(random_seed)
batch_sizes = [int(2**6), int(2**6)]
[ts.update({
    "batch_size": batch_sizes[i],
    "random_seed": random_seed
}) for i, ts in enumerate(training_settings)]

train_loaders = [DataLoader(train_generator_data, batch_size=batch_sizes[i], shuffle=True) for i, train_generator_data in enumerate(train_generator_datas)]
valid_loaders = [DataLoader(valid_generator_data, batch_size=batch_sizes[i], shuffle=False) for i, valid_generator_data in enumerate(valid_generator_datas)]

# %% [markdown]
# ## Construct the model

# %%
inputs = 16
hidden_nodes = [128, 128, 128]
outputs = 1

models = [utils.models.Classifier(inputs, hidden_nodes, outputs).to(DEVICE) for _ in range(NUM_MODELS)]
print(models)
print("----------")

#model = model.to(DEVICE)

learning_rate = 1e-3
optimizers = [torch.optim.Adam(model.parameters(), lr=learning_rate) for model in models]

[ts.update({
    "learning_rate": learning_rate,
    "optimizer": "Adam"
}) for ts in training_settings]
# Out:
# [Classifier(
#   (model): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# ), Classifier(
#   (model): Sequential(
#     (0): Linear(in_features=16, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )]
# ----------
# [None, None]

# %% [markdown]
# ## Perform the training

# %%
for i in range(NUM_MODELS):
    modpath = osp.join("models/classifier{}_subdensity_{}_batch{}".format(TEST_NUM, ''.join(submodel_names[combos[i]]), batch_sizes[i]))
    model = models[i]
    optimizer = optimizers[i]
    X_scaler = X_scalers[i]
    train_weight_norm = train_weight_norms[i]
    valid_weight_norm = valid_weight_norms[i]
    train_loader = train_loaders[i]
    valid_loader = valid_loaders[i]
    lossfunction = 'bce' #'bce', 'sqrt'
    regularization = 0 #1e-5 #0.01
    
    n_epochs = 1500
    stale_epochs = 0
    best_valid_loss = 99999
    patience = [15, 15]
    max_num_batches = int(int(2e4) / batch_sizes[i])
    t = tqdm(range(0, n_epochs))
    
    training_losses = [utils.train.test(
            model,
            train_loader,
            X_scaler,
            weight_norm=train_weight_norm,
            max_num_batches=max_num_batches,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=False
        )[0],]
    validation_losses = [utils.train.test(
            model,
            valid_loader,
            X_scaler,
            weight_norm=valid_weight_norm,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=False
        )[0],]
    
    
    for epoch in t:
        loss = utils.train.train(
            model,
            optimizer,
            train_loader,
            X_scaler,
            weight_norm=train_weight_norm,
            max_num_batches=max_num_batches,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=bool(epoch == n_epochs - 1),
        )
        #loss -= optimal_train_loss
        training_losses.append(loss[0])
    
        valid_loss = utils.train.test(
            model,
            valid_loader,
            X_scaler,
            weight_norm=valid_weight_norm,
            loss=lossfunction,
            regularization=regularization,
            device=DEVICE,
            progress_bar=False,
            leave=bool(epoch == n_epochs - 1),
        )
        #valid_loss -= optimal_valid_loss
        validation_losses.append(valid_loss[0])
        print("Epoch: {:02d}, Training Loss:   {:.4f}".format(epoch, loss[1]))
        print("           Validation Loss: {:.4f}".format(valid_loss[1]))
    
        if valid_loss[1] < best_valid_loss:
            best_valid_loss = valid_loss[1]
            training_settings[i].update({
                "n_epochs": epoch+1,
                "training_losses": training_losses,
                "validation_losses": validation_losses
            })
            model_metadata = utils.train.get_model_metadata(training_settings[i], model, X_scaler, train_weight_norm)
            utils.train.save_model_data(model, model_metadata, name=modpath, save_onnx=False, device=DEVICE)
            print("New best model saved to: {}.zip".format(modpath))
            stale_epochs = 0
        else:
            print("Stale epoch")
            stale_epochs += 1
        if stale_epochs >= patience[i]:
            print("Early stopping after %i stale epochs" % patience[i])
            break
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch: 00, Training Loss:   0.6391
#            Validation Loss: 0.6379
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 01, Training Loss:   0.6172
#            Validation Loss: 0.6152
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 02, Training Loss:   0.6190
#            Validation Loss: 0.6108
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 03, Training Loss:   0.6113
#            Validation Loss: 0.6104
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 04, Training Loss:   0.6078
#            Validation Loss: 0.6022
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 05, Training Loss:   0.6036
#            Validation Loss: 0.6064
# Stale epoch
# Epoch: 06, Training Loss:   0.5979
#            Validation Loss: 0.6029
# Stale epoch
# Epoch: 07, Training Loss:   0.6033
#            Validation Loss: 0.6015
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 08, Training Loss:   0.6061
#            Validation Loss: 0.6010
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 09, Training Loss:   0.5995
#            Validation Loss: 0.6011
# Stale epoch
# Epoch: 10, Training Loss:   0.6031
#            Validation Loss: 0.5988
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 11, Training Loss:   0.6036
#            Validation Loss: 0.5988
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 12, Training Loss:   0.5964
#            Validation Loss: 0.6008
# Stale epoch
# Epoch: 13, Training Loss:   0.5987
#            Validation Loss: 0.5988
# Stale epoch
# Epoch: 14, Training Loss:   0.5979
#            Validation Loss: 0.5988
# Stale epoch
# Epoch: 15, Training Loss:   0.5969
#            Validation Loss: 0.5964
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 16, Training Loss:   0.5973
#            Validation Loss: 0.6043
# Stale epoch
# Epoch: 17, Training Loss:   0.5979
#            Validation Loss: 0.5995
# Stale epoch
# Epoch: 18, Training Loss:   0.5953
#            Validation Loss: 0.5976
# Stale epoch
# Epoch: 19, Training Loss:   0.5959
#            Validation Loss: 0.5969
# Stale epoch
# Epoch: 20, Training Loss:   0.5943
#            Validation Loss: 0.5967
# Stale epoch
# Epoch: 21, Training Loss:   0.5948
#            Validation Loss: 0.5959
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 22, Training Loss:   0.5973
#            Validation Loss: 0.5965
# Stale epoch
# Epoch: 23, Training Loss:   0.5957
#            Validation Loss: 0.5952
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 24, Training Loss:   0.5956
#            Validation Loss: 0.5972
# Stale epoch
# Epoch: 25, Training Loss:   0.5932
#            Validation Loss: 0.5966
# Stale epoch
# Epoch: 26, Training Loss:   0.5947
#            Validation Loss: 0.5955
# Stale epoch
# Epoch: 27, Training Loss:   0.5953
#            Validation Loss: 0.5950
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 28, Training Loss:   0.5955
#            Validation Loss: 0.5955
# Stale epoch
# Epoch: 29, Training Loss:   0.5933
#            Validation Loss: 0.5949
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 30, Training Loss:   0.5912
#            Validation Loss: 0.6030
# Stale epoch
# Epoch: 31, Training Loss:   0.5918
#            Validation Loss: 0.5968
# Stale epoch
# Epoch: 32, Training Loss:   0.5885
#            Validation Loss: 0.5955
# Stale epoch
# Epoch: 33, Training Loss:   0.5871
#            Validation Loss: 0.5990
# Stale epoch
# Epoch: 34, Training Loss:   0.5982
#            Validation Loss: 0.5944
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 35, Training Loss:   0.5912
#            Validation Loss: 0.5945
# Stale epoch
# Epoch: 36, Training Loss:   0.5941
#            Validation Loss: 0.5949
# Stale epoch
# Epoch: 37, Training Loss:   0.5882
#            Validation Loss: 0.5953
# Stale epoch
# Epoch: 38, Training Loss:   0.5930
#            Validation Loss: 0.5946
# Stale epoch
# Epoch: 39, Training Loss:   0.5945
#            Validation Loss: 0.5945
# Stale epoch
# Epoch: 40, Training Loss:   0.5929
#            Validation Loss: 0.5959
# Stale epoch
# Epoch: 41, Training Loss:   0.5918
#            Validation Loss: 0.5939
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 42, Training Loss:   0.5907
#            Validation Loss: 0.5974
# Stale epoch
# Epoch: 43, Training Loss:   0.5894
#            Validation Loss: 0.5965
# Stale epoch
# Epoch: 44, Training Loss:   0.5922
#            Validation Loss: 0.5948
# Stale epoch
# Epoch: 45, Training Loss:   0.5903
#            Validation Loss: 0.5949
# Stale epoch
# Epoch: 46, Training Loss:   0.5918
#            Validation Loss: 0.5940
# Stale epoch
# Epoch: 47, Training Loss:   0.5940
#            Validation Loss: 0.5945
# Stale epoch
# Epoch: 48, Training Loss:   0.5926
#            Validation Loss: 0.5941
# Stale epoch
# Epoch: 49, Training Loss:   0.5874
#            Validation Loss: 0.5931
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 50, Training Loss:   0.5891
#            Validation Loss: 0.5936
# Stale epoch
# Epoch: 51, Training Loss:   0.5889
#            Validation Loss: 0.5941
# Stale epoch
# Epoch: 52, Training Loss:   0.5931
#            Validation Loss: 0.5945
# Stale epoch
# Epoch: 53, Training Loss:   0.5888
#            Validation Loss: 0.5946
# Stale epoch
# Epoch: 54, Training Loss:   0.5914
#            Validation Loss: 0.5931
# Stale epoch
# Epoch: 55, Training Loss:   0.5899
#            Validation Loss: 0.5950
# Stale epoch
# Epoch: 56, Training Loss:   0.5960
#            Validation Loss: 0.5938
# Stale epoch
# Epoch: 57, Training Loss:   0.5937
#            Validation Loss: 0.5931
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 58, Training Loss:   0.5916
#            Validation Loss: 0.5943
# Stale epoch
# Epoch: 59, Training Loss:   0.5922
#            Validation Loss: 0.5930
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 60, Training Loss:   0.5891
#            Validation Loss: 0.5930
# Stale epoch
# Epoch: 61, Training Loss:   0.5932
#            Validation Loss: 0.5946
# Stale epoch
# Epoch: 62, Training Loss:   0.5901
#            Validation Loss: 0.5935
# Stale epoch
# Epoch: 63, Training Loss:   0.5945
#            Validation Loss: 0.5925
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 64, Training Loss:   0.5931
#            Validation Loss: 0.5937
# Stale epoch
# Epoch: 65, Training Loss:   0.5861
#            Validation Loss: 0.5936
# Stale epoch
# Epoch: 66, Training Loss:   0.5854
#            Validation Loss: 0.5940
# Stale epoch
# Epoch: 67, Training Loss:   0.5884
#            Validation Loss: 0.5926
# Stale epoch
# Epoch: 68, Training Loss:   0.5914
#            Validation Loss: 0.5936
# Stale epoch
# Epoch: 69, Training Loss:   0.5919
#            Validation Loss: 0.5934
# Stale epoch
# Epoch: 70, Training Loss:   0.5906
#            Validation Loss: 0.5934
# Stale epoch
# Epoch: 71, Training Loss:   0.5891
#            Validation Loss: 0.5941
# Stale epoch
# Epoch: 72, Training Loss:   0.5902
#            Validation Loss: 0.5931
# Stale epoch
# Epoch: 73, Training Loss:   0.5861
#            Validation Loss: 0.5931
# Stale epoch
# Epoch: 74, Training Loss:   0.5917
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 75, Training Loss:   0.5877
#            Validation Loss: 0.5929
# Stale epoch
# Epoch: 76, Training Loss:   0.5898
#            Validation Loss: 0.5930
# Stale epoch
# Epoch: 77, Training Loss:   0.5931
#            Validation Loss: 0.5925
# Stale epoch
# Epoch: 78, Training Loss:   0.5858
#            Validation Loss: 0.5920
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 79, Training Loss:   0.5873
#            Validation Loss: 0.5913
# New best model saved to: models/classifier_subdensity_PosPos_batch64.zip
# Epoch: 80, Training Loss:   0.5903
#            Validation Loss: 0.5946
# Stale epoch
# Epoch: 81, Training Loss:   0.5903
#            Validation Loss: 0.5943
# Stale epoch
# Epoch: 82, Training Loss:   0.5850
#            Validation Loss: 0.5951
# Stale epoch
# Epoch: 83, Training Loss:   0.5939
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 84, Training Loss:   0.5919
#            Validation Loss: 0.5944
# Stale epoch
# Epoch: 85, Training Loss:   0.5912
#            Validation Loss: 0.5920
# Stale epoch
# Epoch: 86, Training Loss:   0.5851
#            Validation Loss: 0.5941
# Stale epoch
# Epoch: 87, Training Loss:   0.5906
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 88, Training Loss:   0.5851
#            Validation Loss: 0.5925
# Stale epoch
# Epoch: 89, Training Loss:   0.5906
#            Validation Loss: 0.5921
# Stale epoch
# Epoch: 90, Training Loss:   0.5910
#            Validation Loss: 0.5917
# Stale epoch
# Epoch: 91, Training Loss:   0.5904
#            Validation Loss: 0.5932
# Stale epoch
# Epoch: 92, Training Loss:   0.5879
#            Validation Loss: 0.5920
# Stale epoch
# Epoch: 93, Training Loss:   0.5892
#            Validation Loss: 0.5919
# Stale epoch
# Epoch: 94, Training Loss:   0.5927
#            Validation Loss: 0.5939
# Stale epoch
# Early stopping after 15 stale epochs
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Epoch: 00, Training Loss:   0.4051
#            Validation Loss: 0.3279
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 01, Training Loss:   0.3066
#            Validation Loss: 0.3030
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 02, Training Loss:   0.2846
#            Validation Loss: 0.2817
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 03, Training Loss:   0.2742
#            Validation Loss: 0.2775
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 04, Training Loss:   0.2641
#            Validation Loss: 0.2771
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 05, Training Loss:   0.2607
#            Validation Loss: 0.2661
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 06, Training Loss:   0.2546
#            Validation Loss: 0.2728
# Stale epoch
# Epoch: 07, Training Loss:   0.2576
#            Validation Loss: 0.2581
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 08, Training Loss:   0.2517
#            Validation Loss: 0.2613
# Stale epoch
# Epoch: 09, Training Loss:   0.2535
#            Validation Loss: 0.2484
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 10, Training Loss:   0.2540
#            Validation Loss: 0.2499
# Stale epoch
# Epoch: 11, Training Loss:   0.2475
#            Validation Loss: 0.2508
# Stale epoch
# Epoch: 12, Training Loss:   0.2413
#            Validation Loss: 0.2554
# Stale epoch
# Epoch: 13, Training Loss:   0.2441
#            Validation Loss: 0.2483
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 14, Training Loss:   0.2490
#            Validation Loss: 0.2553
# Stale epoch
# Epoch: 15, Training Loss:   0.2377
#            Validation Loss: 0.2500
# Stale epoch
# Epoch: 16, Training Loss:   0.2379
#            Validation Loss: 0.2526
# Stale epoch
# Epoch: 17, Training Loss:   0.2417
#            Validation Loss: 0.2521
# Stale epoch
# Epoch: 18, Training Loss:   0.2319
#            Validation Loss: 0.2458
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 19, Training Loss:   0.2400
#            Validation Loss: 0.2405
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 20, Training Loss:   0.2430
#            Validation Loss: 0.2405
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 21, Training Loss:   0.2404
#            Validation Loss: 0.2425
# Stale epoch
# Epoch: 22, Training Loss:   0.2353
#            Validation Loss: 0.2415
# Stale epoch
# Epoch: 23, Training Loss:   0.2346
#            Validation Loss: 0.2431
# Stale epoch
# Epoch: 24, Training Loss:   0.2378
#            Validation Loss: 0.2382
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 25, Training Loss:   0.2433
#            Validation Loss: 0.2389
# Stale epoch
# Epoch: 26, Training Loss:   0.2295
#            Validation Loss: 0.2384
# Stale epoch
# Epoch: 27, Training Loss:   0.2371
#            Validation Loss: 0.2408
# Stale epoch
# Epoch: 28, Training Loss:   0.2281
#            Validation Loss: 0.2463
# Stale epoch
# Epoch: 29, Training Loss:   0.2373
#            Validation Loss: 0.2374
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 30, Training Loss:   0.2395
#            Validation Loss: 0.2376
# Stale epoch
# Epoch: 31, Training Loss:   0.2313
#            Validation Loss: 0.2403
# Stale epoch
# Epoch: 32, Training Loss:   0.2335
#            Validation Loss: 0.2431
# Stale epoch
# Epoch: 33, Training Loss:   0.2305
#            Validation Loss: 0.2340
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 34, Training Loss:   0.2304
#            Validation Loss: 0.2386
# Stale epoch
# Epoch: 35, Training Loss:   0.2345
#            Validation Loss: 0.2352
# Stale epoch
# Epoch: 36, Training Loss:   0.2337
#            Validation Loss: 0.2341
# Stale epoch
# Epoch: 37, Training Loss:   0.2262
#            Validation Loss: 0.2369
# Stale epoch
# Epoch: 38, Training Loss:   0.2333
#            Validation Loss: 0.2340
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 39, Training Loss:   0.2296
#            Validation Loss: 0.2329
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 40, Training Loss:   0.2290
#            Validation Loss: 0.2334
# Stale epoch
# Epoch: 41, Training Loss:   0.2282
#            Validation Loss: 0.2391
# Stale epoch
# Epoch: 42, Training Loss:   0.2290
#            Validation Loss: 0.2334
# Stale epoch
# Epoch: 43, Training Loss:   0.2314
#            Validation Loss: 0.2323
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 44, Training Loss:   0.2218
#            Validation Loss: 0.2338
# Stale epoch
# Epoch: 45, Training Loss:   0.2226
#            Validation Loss: 0.2319
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 46, Training Loss:   0.2273
#            Validation Loss: 0.2371
# Stale epoch
# Epoch: 47, Training Loss:   0.2216
#            Validation Loss: 0.2363
# Stale epoch
# Epoch: 48, Training Loss:   0.2257
#            Validation Loss: 0.2350
# Stale epoch
# Epoch: 49, Training Loss:   0.2195
#            Validation Loss: 0.2317
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 50, Training Loss:   0.2303
#            Validation Loss: 0.2328
# Stale epoch
# Epoch: 51, Training Loss:   0.2282
#            Validation Loss: 0.2305
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 52, Training Loss:   0.2302
#            Validation Loss: 0.2348
# Stale epoch
# Epoch: 53, Training Loss:   0.2295
#            Validation Loss: 0.2366
# Stale epoch
# Epoch: 54, Training Loss:   0.2309
#            Validation Loss: 0.2303
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 55, Training Loss:   0.2185
#            Validation Loss: 0.2313
# Stale epoch
# Epoch: 56, Training Loss:   0.2267
#            Validation Loss: 0.2337
# Stale epoch
# Epoch: 57, Training Loss:   0.2245
#            Validation Loss: 0.2344
# Stale epoch
# Epoch: 58, Training Loss:   0.2256
#            Validation Loss: 0.2309
# Stale epoch
# Epoch: 59, Training Loss:   0.2291
#            Validation Loss: 0.2287
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 60, Training Loss:   0.2239
#            Validation Loss: 0.2308
# Stale epoch
# Epoch: 61, Training Loss:   0.2249
#            Validation Loss: 0.2338
# Stale epoch
# Epoch: 62, Training Loss:   0.2229
#            Validation Loss: 0.2411
# Stale epoch
# Epoch: 63, Training Loss:   0.2275
#            Validation Loss: 0.2302
# Stale epoch
# Epoch: 64, Training Loss:   0.2253
#            Validation Loss: 0.2325
# Stale epoch
# Epoch: 65, Training Loss:   0.2313
#            Validation Loss: 0.2336
# Stale epoch
# Epoch: 66, Training Loss:   0.2204
#            Validation Loss: 0.2304
# Stale epoch
# Epoch: 67, Training Loss:   0.2242
#            Validation Loss: 0.2283
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 68, Training Loss:   0.2248
#            Validation Loss: 0.2304
# Stale epoch
# Epoch: 69, Training Loss:   0.2200
#            Validation Loss: 0.2291
# Stale epoch
# Epoch: 70, Training Loss:   0.2200
#            Validation Loss: 0.2302
# Stale epoch
# Epoch: 71, Training Loss:   0.2233
#            Validation Loss: 0.2296
# Stale epoch
# Epoch: 72, Training Loss:   0.2161
#            Validation Loss: 0.2280
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 73, Training Loss:   0.2233
#            Validation Loss: 0.2312
# Stale epoch
# Epoch: 74, Training Loss:   0.2196
#            Validation Loss: 0.2292
# Stale epoch
# Epoch: 75, Training Loss:   0.2192
#            Validation Loss: 0.2326
# Stale epoch
# Epoch: 76, Training Loss:   0.2230
#            Validation Loss: 0.2300
# Stale epoch
# Epoch: 77, Training Loss:   0.2214
#            Validation Loss: 0.2302
# Stale epoch
# Epoch: 78, Training Loss:   0.2287
#            Validation Loss: 0.2293
# Stale epoch
# Epoch: 79, Training Loss:   0.2169
#            Validation Loss: 0.2309
# Stale epoch
# Epoch: 80, Training Loss:   0.2226
#            Validation Loss: 0.2295
# Stale epoch
# Epoch: 81, Training Loss:   0.2226
#            Validation Loss: 0.2296
# Stale epoch
# Epoch: 82, Training Loss:   0.2208
#            Validation Loss: 0.2304
# Stale epoch
# Epoch: 83, Training Loss:   0.2141
#            Validation Loss: 0.2301
# Stale epoch
# Epoch: 84, Training Loss:   0.2214
#            Validation Loss: 0.2301
# Stale epoch
# Epoch: 85, Training Loss:   0.2186
#            Validation Loss: 0.2274
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 86, Training Loss:   0.2233
#            Validation Loss: 0.2341
# Stale epoch
# Epoch: 87, Training Loss:   0.2156
#            Validation Loss: 0.2267
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 88, Training Loss:   0.2165
#            Validation Loss: 0.2293
# Stale epoch
# Epoch: 89, Training Loss:   0.2192
#            Validation Loss: 0.2276
# Stale epoch
# Epoch: 90, Training Loss:   0.2166
#            Validation Loss: 0.2297
# Stale epoch
# Epoch: 91, Training Loss:   0.2185
#            Validation Loss: 0.2301
# Stale epoch
# Epoch: 92, Training Loss:   0.2199
#            Validation Loss: 0.2289
# Stale epoch
# Epoch: 93, Training Loss:   0.2147
#            Validation Loss: 0.2259
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 94, Training Loss:   0.2162
#            Validation Loss: 0.2275
# Stale epoch
# Epoch: 95, Training Loss:   0.2170
#            Validation Loss: 0.2294
# Stale epoch
# Epoch: 96, Training Loss:   0.2140
#            Validation Loss: 0.2265
# Stale epoch
# Epoch: 97, Training Loss:   0.2145
#            Validation Loss: 0.2306
# Stale epoch
# Epoch: 98, Training Loss:   0.2153
#            Validation Loss: 0.2274
# Stale epoch
# Epoch: 99, Training Loss:   0.2234
#            Validation Loss: 0.2281
# Stale epoch
# Epoch: 100, Training Loss:   0.2192
#            Validation Loss: 0.2240
# New best model saved to: models/classifier_subdensity_PosNeg_batch64.zip
# Epoch: 101, Training Loss:   0.2096
#            Validation Loss: 0.2295
# Stale epoch
# Epoch: 102, Training Loss:   0.2166
#            Validation Loss: 0.2300
# Stale epoch
# Epoch: 103, Training Loss:   0.2115
#            Validation Loss: 0.2262
# Stale epoch
# Epoch: 104, Training Loss:   0.2144
#            Validation Loss: 0.2246
# Stale epoch
# Epoch: 105, Training Loss:   0.2123
#            Validation Loss: 0.2268
# Stale epoch
# Epoch: 106, Training Loss:   0.2175
#            Validation Loss: 0.2274
# Stale epoch
# Epoch: 107, Training Loss:   0.2138
#            Validation Loss: 0.2282
# Stale epoch
# Epoch: 108, Training Loss:   0.2108
#            Validation Loss: 0.2255
# Stale epoch
# Epoch: 109, Training Loss:   0.2173
#            Validation Loss: 0.2259
# Stale epoch
# Epoch: 110, Training Loss:   0.2158
#            Validation Loss: 0.2255
# Stale epoch
# Epoch: 111, Training Loss:   0.2145
#            Validation Loss: 0.2272
# Stale epoch
# Epoch: 112, Training Loss:   0.2122
#            Validation Loss: 0.2274
# Stale epoch
# Epoch: 113, Training Loss:   0.2159
#            Validation Loss: 0.2266
# Stale epoch
# Epoch: 114, Training Loss:   0.2103
#            Validation Loss: 0.2280
# Stale epoch
# Epoch: 115, Training Loss:   0.2153
#            Validation Loss: 0.2249
# Stale epoch
# Early stopping after 15 stale epochs
